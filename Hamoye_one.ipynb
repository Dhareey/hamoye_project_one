# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv')

# %%
# View the data head
data.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
# Check data summary
data.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
# Question 3. Lowest average fuel cost per unit burned
data.groupby('fuel_type_code_pudl').mean()['fuel_cost_per_unit_burned']
# Out:
# fuel_type_code_pudl
# coal         67.421830
# gas          13.659397
# nuclear    4955.157002
# oil         168.877086
# other        18.253856
# waste        19.518122
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
# Question 4a Standard deviation
data.fuel_mmbtu_per_unit.std()
# Out:
# 10.600220307806886

# %%
# Question 4b. 7th percentile
data.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
# QUestion 5. Skewness and kurtoisness in two decimal places
print(round(data['fuel_qty_burned'].skew(),2))
print(round(data['fuel_qty_burned'].kurt(),2))
# Out:
# 15.85
# 651.37

# %%
# Question 6a Which feature has missing values
data.isnull().any()
# Out:
# record_id                       False
# utility_id_ferc1                False
# report_year                     False
# plant_name_ferc1                False
# fuel_type_code_pudl             False
# fuel_unit                        True
# fuel_qty_burned                 False
# fuel_mmbtu_per_unit             False
# fuel_cost_per_unit_burned       False
# fuel_cost_per_unit_delivered    False
# fuel_cost_per_mmbtu             False
# dtype: bool

# %%
# Question 6b and c. Total number of missing values and its percentage
print(data['fuel_unit'].isnull().sum())
print(round((data['fuel_unit'].isnull().sum()/29523)*100,3))
# Out:
# 180
# 0.61

# %%
# Question 7 = 6a

# %%
# Question 8 Lowest correlation with Fuel Cost per Unit burned
data.corr()
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# report_year                           0.093323     1.000000         0.012952
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_unit_burned            -0.037863     0.013599        -0.018535
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# report_year                             -0.110853                   0.013599
# fuel_qty_burned                         -0.080946                  -0.018535
# ...

# %%
#Question 9. PErcentage change in fuel cost per unit burned in 1998 compared to 1994
data.groupby(['fuel_type_code_pudl','report_year']).sum()
# Out:
#                                  utility_id_ferc1  fuel_qty_burned  \
# fuel_type_code_pudl report_year
# coal                1994                    50430     7.172082e+08
#                     1995                    51231     1.257398e+09
#                     1996                    45720     6.988514e+08
#                     1997                    44254     8.169024e+08
#                     1998                    46403     8.982095e+08
#                     1999                    45126     8.805301e+08
#                     2000                    44271     8.620492e+08
#                     2001                    40232     8.564316e+08
#                     2002                    38592     8.144357e+08
#                     2003                    38876     8.018815e+08
#                     2004                    38246     7.735318e+08
#                     2005                    37923     6.046304e+08
# ...

# %%
data.groupby(['fuel_type_code_pudl','report_year'])['fuel_cost_per_unit_burned'].pct_change()
# Out:
# 0              NaN
# 1        -0.000538
# 2         1.137783
# 3         0.188570
# 4              NaN
# 5        -0.062910
# 6              NaN
# 7         0.323237
# 8        -0.419713
# 9        -0.154254
# 10       -0.299639
# 11       -0.000696
# 12        0.000000
# 13        0.053570
# 14             NaN
# 15        0.467998
# 16       -0.002072
# 17       -0.181531
# 18        0.268997
# 19        0.037068
# 20       -0.132822
# 21       -0.090093
# 22       -0.001528
# 23        0.061513
# 24        0.007378
# 25        0.000062
# 26       -0.214827
# 27        0.014416
# 28        0.283505
# 29       -0.328363
#            ...
# 29493     1.689139
# 29494    -0.309502
# 29495     0.071459
# 29496    -0.478261
# 29497     0.581186
# 29498     0.232274
# 29499     0.077371
# 29500     0.003702
# 29501     0.028864
# 29502    -0.135967
# 29503    -0.101480
# 29504     0.383157
# 29505     0.144286
# 29506    -0.057239
# 29507     0.027740
# 29508    39.643927
# ...

# %%
#Question 10.Highest average fuel cost per unit delivered
data.groupby('report_year').mean()['fuel_cost_per_unit_delivered']
# Out:
# report_year
# 1994       63.636060
# 1995       32.735269
# 1996     9196.705948
# 1997    11140.197239
# 1998      287.154420
# 1999       25.551627
# 2000      985.362877
# 2001       60.050396
# 2002       47.594361
# 2003       55.663493
# 2004      139.524275
# 2005       41.438184
# 2006       38.657484
# 2007       43.325023
# 2008       58.588197
# 2009      652.694163
# 2010       91.862105
# 2011       59.774667
# 2012       60.994502
# 2013      172.307591
# 2014      192.737183
# 2015      326.535511
# 2016      103.901761
# 2017       46.196861
# 2018      499.269966
# Name: fuel_cost_per_unit_delivered, dtype: float64

# %%
11902.597
14984.572
